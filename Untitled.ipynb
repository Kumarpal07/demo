# %%
import pandas as pd
import numpy as np

# %%
data=[10,20,30,40,40]
s=pd.Series(data,index=['A','B','C','D','E'],name='K')
print(s)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    40
# Name: K, dtype: int64

# %%
d=pd.read_csv('Book1.csv')
print(type(d))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(s.min())
print(s.max())
print(s.count())
print(s.mean())
print(s.median())
print(s.size)
print(s.shape)
print(s.mode())
# Out:
# 10
# 40
# 5
# 28.0
# 30.0
# 5
# (5,)
# 0    40
# dtype: int64

# %%
d=[[10,20,30,40,40],[10,20,30,40,40],[10,20,30,40,40],[10,20,30,40,40]]
d=pd.DataFrame(d,columns=['A','B','C','D','E'])
d
# Out:
#     A   B   C   D   E
# 0  10  20  30  40  40
# 1  10  20  30  40  40
# 2  10  20  30  40  40
# 3  10  20  30  40  40

# %%
d=pd.read_csv('ipl-matches.csv')
d
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
d.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
d.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
d.sample(2)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 330  1082634  Hyderabad  2017-05-06     2017          44
# 143  1216502        NaN  2020-10-31  2020/21          52
#
#                            Team1                   Team2  \
# 330          Sunrisers Hyderabad  Rising Pune Supergiant
# 143  Royal Challengers Bangalore     Sunrisers Hyderabad
#
#                                          Venue           TossWinner  \
# 330  Rajiv Gandhi International Stadium, Uppal  Sunrisers Hyderabad
# 143                    Sharjah Cricket Stadium  Sunrisers Hyderabad
#
#     TossDecision SuperOver             WinningTeam    WonBy  Margin method  \
# 330        field         N  Rising Pune Supergiant     Runs    12.0    NaN
# 143        field         N     Sunrisers Hyderabad  Wickets     5.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 330      JD Unadkat  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# ...

# %%
d['MatchNumber'].value_counts()
# Out:
# 49                    15
# 1                     15
# 51                    15
# 41                    15
# 53                    15
#                       ..
# 67                     4
# Elimination Final      3
# 72                     2
# 71                     2
# 3rd Place Play-Off     1
# Name: MatchNumber, Length: 80, dtype: int64

# %%
d.describe(include='all')
# Out:
#                   ID    City        Date Season MatchNumber  \
# count   9.500000e+02     899         950    950         950
# unique           NaN      33         706     15          80
# top              NaN  Mumbai  2011-05-10   2013          49
# freq             NaN     159           2     76          15
# mean    8.304852e+05     NaN         NaN    NaN         NaN
# std     3.375678e+05     NaN         NaN    NaN         NaN
# min     3.359820e+05     NaN         NaN    NaN         NaN
# 25%     5.012612e+05     NaN         NaN    NaN         NaN
# 50%     8.297380e+05     NaN         NaN    NaN         NaN
# 75%     1.175372e+06     NaN         NaN    NaN         NaN
# max     1.312200e+06     NaN         NaN    NaN         NaN
#
#                               Team1           Team2         Venue  \
# count                           950             950           950
# unique                           18              18            49
# ...

# %%
d.describe(percentiles=[0.2,0.4,0.6])
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 20%    5.012128e+05    5.000000
# 40%    5.980556e+05    7.000000
# 50%    8.297380e+05    8.000000
# 60%    9.810058e+05    9.000000
# max    1.312200e+06  146.000000

# %%
d.iloc[1,1]
# Out:
# 'Ahmedabad'

# %%
d.iloc[1:2,1]
# Out:
# 1    Ahmedabad
# Name: City, dtype: object

# %%
d.iloc[1:2,1:2]
# Out:
#         City
# 1  Ahmedabad

# %%
d.iloc[1:10:2,-1:-8:-1]
# Out:
#             Umpire2                Umpire1  \
# 1       Nitin Menon            CB Gaffaney
# 3         VK Sharma           BNJ Oxenford
# 5      Tapan Sharma            Nitin Menon
# 7  GR Sadashiv Iyer  KN Ananthapadmanabhan
# 9          N Pandit            CB Gaffaney
#
#                                         Team2Players  \
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# 5  ['Ishan Kishan', 'RG Sharma', 'D Brevis', 'Til...
# 7  ['V Kohli', 'F du Plessis', 'GJ Maxwell', 'KD ...
# 9  ['RG Sharma', 'Ishan Kishan', 'DR Sams', 'Tila...
#
#                                         Team1Players Player_of_Match method  \
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...      JC Buttler    NaN
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...       DA Miller    NaN
# 5  ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...       JJ Bumrah    NaN
# ...

# %%
d.iloc[1,1:5]
# Out:
# City             Ahmedabad
# Date            2022-05-27
# Season                2022
# MatchNumber    Qualifier 2
# Name: 1, dtype: object

# %%
import seaborn as sns

# %%
d=pd.read_csv('auto-mpg.csv')

# %%
df=d.loc[d['horsepower']!='?']
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
sns.boxplot(data=df['horsepower'])

# %%
sns.boxplot(data=d['acceleration'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Matrix

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df,figsize=(20,20))
plt.show()

# %%
pd.crosstab(df['model year'],df['cylinders'],margins=True)
# Out:
# cylinders   3    4  5   6    8  All
# model year
# 70          0    7  0   4   18   29
# 71          0   12  0   8    7   27
# 72          1   14  0   0   13   28
# 73          1   11  0   8   20   40
# 74          0   15  0   6    5   26
# 75          0   12  0  12    6   30
# 76          0   15  0  10    9   34
# 77          1   14  0   5    8   28
# 78          0   17  1  12    6   36
# 79          0   12  1   6   10   29
# 80          1   23  1   2    0   27
# 81          0   20  0   7    1   28
# 82          0   27  0   3    0   30
# All         4  199  3  83  103  392

# %%
pd.plotting.parallel_coordinates(df,class_column='cylinders',cols=['acceleration','mpg','origin'])
plt.show()
